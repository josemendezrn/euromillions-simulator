# %% [markdown]
# ## José Méndez / 2025-1542

# %% [markdown]
# ## Reto # 5 - Programación II
# * Para este reto, utilizaremos la librería "Random" y lo haremos con el uso de Funciones, Loops y condicionales.
# * Simularemos el juego de "Lotería" europeo "EUROMILLION"
# * Dentro de los requisitos, debemos de preguntarele la usuario qué cantidad de combinaciones de EUROMILLONES desea producir o generar. Debemos imprimir cada combinación ordenadas con un índice numérico (Com. 1, Com. 2...). La generación de c0ombinaciones debe ser empleando las funciones con parámetros dados por el usuario (cantidad de combinaciones).

# %%
import random

# BLOQUE 1
# Función para generar las combinaciones de #'s del 1 al 50 y las estrellas
def generar_combinacion(n_combinaciones):
    todas_las_jugadas =  []
    
    # bucle para extraer cada valro inidvidual en varias vueltas
    for _ in range(n_combinaciones):
        num_5 = random.sample(range(1, 51), 5)
        star_2 = random.sample(range(1, 13), 2)
        # Creamos un diccionario para almacenar
        jugada = {"numeros": num_5, "estrellas": star_2}
        todas_las_jugadas.append(jugada)

    # retornamos el resultado almacenado en "todas_las_jugadas"
    return todas_las_jugadas


# BLOQUE 2
# Acá le pediremos al usuario ingresar qué cantidad de COMBINACIONES de EUROMILLION quiere producir.
while True:
    numero = input('¿Cuántas combinaciones de EUROMILLONES deseas imprimir?\nLetra "q" si deseas cancelar').lower()

    # Salida para cancelar el código
    if numero == 'q'.lower():
        break

    # Ahora crearemos el prueba-error con el valor que el usuario va a introducir arriba...
    try:
        numero2 = int(numero)
        # llamamos la función y atraparemos el resultado de la misma en una varible (resultado)
        resultado = generar_combinacion(numero2)

        # Imprimimos los resultados para cumplir el reto
        print('\n-----------------------Tus Combinaciones---------------------------')
        for i, juego in enumerate(resultado, start=1):
            print(f"Combinación {i}: Números: {juego['numeros']}  |  Estrellas: {juego['estrellas']}")
        print("===================================================================\n")


    except ValueError:
        print("No válido, inténtalo de nuevo... Introduce un # entero o 'q' para salir: \n")
        continue
# Out:
# -----------------------Tus Combinaciones---------------------------
# Combinación 1: Números: [10, 38, 20, 43, 23]  |  Estrellas: [4, 5]
# Combinación 2: Números: [7, 18, 10, 14, 35]  |  Estrellas: [3, 10]
# Combinación 3: Números: [13, 39, 30, 38, 1]  |  Estrellas: [11, 4]
# Combinación 4: Números: [50, 37, 43, 15, 45]  |  Estrellas: [11, 9]
# ===================================================================
#
#
# -----------------------Tus Combinaciones---------------------------
# Combinación 1: Números: [48, 7, 43, 35, 32]  |  Estrellas: [2, 12]
# Combinación 2: Números: [34, 5, 24, 46, 32]  |  Estrellas: [12, 3]
# Combinación 3: Números: [37, 42, 35, 15, 3]  |  Estrellas: [6, 4]
# Combinación 4: Números: [31, 36, 17, 48, 19]  |  Estrellas: [7, 8]
# Combinación 5: Números: [42, 31, 18, 11, 10]  |  Estrellas: [7, 8]
# Combinación 6: Números: [45, 9, 12, 34, 6]  |  Estrellas: [4, 5]
# Combinación 7: Números: [13, 4, 14, 28, 26]  |  Estrellas: [5, 10]
# ===================================================================
#
# No válido, inténtalo de nuevo... Introduce un # entero o 'q' para salir:
#
# No válido, inténtalo de nuevo... Introduce un # entero o 'q' para salir:
